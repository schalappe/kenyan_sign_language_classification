# %% [markdown]
# ## Plot images

# %%
from cv2 import imread
from matplotlib import pyplot as plt

# %%
img = imread(
    "/Users/schalappe/Documents/Lab/Engineer/Projects/kenyan_sign_language_classification/data/Images/ImageID_0BGG3W3J.jpg"
)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ## EDA

# %%
from pandas import read_csv

# %%
train = read_csv(
    "/Users/schalappe/Documents/Lab/Engineer/Projects/kenyan_sign_language_classification/data/Train.csv",
    header="infer"
)

# %%
train.head()
# Out:
#             img_IDS             Label
# 0  ImageID_33HMDMJ3            Temple
# 1  ImageID_V5POEX4O            Church
# 2  ImageID_89CCCCW6  Enough/Satisfied
# 3  ImageID_GNJXOWX5                Me
# 4  ImageID_7Q9LOP7R              Love

# %%
train["Label"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Generator

# %%
import sys
sys.path.insert(
    0,
    "/Users/schalappe/Documents/Lab/Engineer/Projects/kenyan_sign_language_classification"
)
from src.data import DatasetGenerator

# %%
train_generator = DatasetGenerator(
    "/Users/schalappe/Documents/Lab/Engineer/Projects/kenyan_sign_language_classification/data/features/train_set.hdf5",
    1,
    False,
    10
)
train = iter(train_generator.generator())

# %%
image, label = next(train)

# %%
label
# Out:
# array([8])

# %%
plt.imshow(image[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image
# Out:
# array([[[[ 88.,  68.,  68.],
#          [ 95.,  78.,  79.],
#          [129., 114., 119.],
#          ...,
#          [199., 173., 157.],
#          [203., 178., 162.],
#          [205., 180., 164.]],
#
#         [[112.,  93.,  89.],
#          [104.,  86.,  85.],
#          [127., 112., 115.],
#          ...,
#          [199., 173., 157.],
#          [202., 177., 161.],
#          [204., 179., 163.]],
#
#         [[118.,  99.,  93.],
#          [150., 131., 128.],
#          [175., 158., 160.],
#          ...,
#          [197., 171., 155.],
#          [200., 175., 159.],
#          [202., 177., 161.]],
#
#         ...,
#
#         [[216., 237., 245.],
#          [222., 242., 249.],
#          [222., 242., 250.],
#          ...,
#          [ 96.,  95.,  97.],
#          [ 83.,  84.,  86.],
#          [ 95.,  96., 100.]],
#
#         [[227., 247., 253.],
#          [226., 246., 252.],
#          [227., 247., 252.],
#          ...,
#          [103., 103., 105.],
#          [ 85.,  86.,  90.],
#          [111., 112., 117.]],
#
#         [[225., 244., 249.],
#          [223., 243., 248.],
#          [222., 241., 246.],
#          ...,
#          [126., 126., 130.],
#          [115., 117., 122.],
#          [122., 125., 130.]]]])
